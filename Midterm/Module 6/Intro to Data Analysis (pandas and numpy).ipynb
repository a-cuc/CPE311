# %% [markdown]
# <a href="https://colab.research.google.com/github/a-cuc/CPE311/blob/main/Intro%20to%20Data%20Analysis%20(pandas%20and%20numpy).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Public Datasets source:
#
# UCI Dataset
#
# IEEE Dataport
#
# Kaggle

# %%
filepath = '/content/Iris.csv'

# %%
import pandas as pd
import numpy as np

# %%
# add documentation whenever necessary
data = pd.read_csv(filepath)

data # called DATAFRAME
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
step_data = [3620, 9466, 7501, 3648, 9751] # uses panda
# panda uses dataframes, 2d arrays

step_counts = pd.Series(step_data, name = 'steps') # uses numpy
# numpy uses series, 1d array

print(step_counts)
# Out:
# 0    3620
# 1    9466
# 2    7501
# 3    3648
# 4    9751
# Name: steps, dtype: int64

# %%
grades = [95.65, 50.25, 33.25, 22.3, 85]
# Make a series for grades using pandas
# Insert your code here
grades_series = pd.Series(grades, name = 'Grades Series')
print(grades_series)
# Out:
# 0    95.65
# 1    50.25
# 2    33.25
# 3    22.30
# 4    85.00
# Name: Grades Series, dtype: float64

# %%
# series are indexed, where it starts at 0
step_counts.index
# Out:
# DatetimeIndex(['2024-03-06', '2024-03-07', '2024-03-08', '2024-03-09',
#                '2024-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
step_counts.index = pd.date_range('20240306', periods=5) # changes the index to date
step_counts
# Out:
# 2024-03-06    3620
# 2024-03-07    9466
# 2024-03-08    7501
# 2024-03-09    3648
# 2024-03-10    9751
# Freq: D, Name: steps, dtype: int64

# %%
# To access data, it can be by naming index value, or the initial index (0-4)
step_counts['2024-03-10']
step_counts[4]
# Out:
# 9751

# %%
# Data can be sliced using index range
step_counts[:-1]
# Out:
# 2024-03-06    3620
# 2024-03-07    9466
# 2024-03-08    7501
# 2024-03-09    3648
# Freq: D, Name: steps, dtype: int64

# %%
step_counts['2024-03']
# Out:
# 2024-03-06    3620
# 2024-03-07    9466
# 2024-03-08    7501
# 2024-03-09    3648
# 2024-03-10    9751
# Freq: D, Name: steps, dtype: int64

# %%
step_counts.dtypes # checks for data type
# Out:
# dtype('int64')

# %%
# we can change data type using numpy
step_counts = step_counts.astype(np.float64)

step_counts.dtypes # checks for data type
# Out:
# dtype('float64')

# %%
step_counts
# Out:
# 2024-03-06    3620.0
# 2024-03-07    9466.0
# 2024-03-08    7501.0
# 2024-03-09    3648.0
# 2024-03-10    9751.0
# Freq: D, Name: steps, dtype: float64

# %%
# However, data is not always clean
step_counts[1:4] = np.NaN
step_counts
# Out:
# 2024-03-06    3620.0
# 2024-03-07       NaN
# 2024-03-08       NaN
# 2024-03-09       NaN
# 2024-03-10    9751.0
# Freq: D, Name: steps, dtype: float64

# %%
# How to deal with missing values?
# Change missing values to average of non-missing values
# Change to 0

step_counts = step_counts.fillna(0.)
step_counts
# Out:
# 2024-03-06    3620.0
# 2024-03-07       0.0
# 2024-03-08       0.0
# 2024-03-09       0.0
# 2024-03-10    9751.0
# Freq: D, Name: steps, dtype: float64

# %% [markdown]
# Pandas Dataframe Creation and Methods

# %%
# Cycling Distance
cycling_data = [10,7,0,None,2,4,15,3,10,9,0,None]

joined_data = list(zip(step_data, cycling_data)) # joins cycling and step data

joined_data
# Out:
# [(3620, 10), (9466, 7), (7501, 0), (3648, None), (9751, 2)]

# %%
# Create Dataframe
activity_df = pd.DataFrame(joined_data)
activity_df
# Out:
#       0     1
# 0  3620  10.0
# 1  9466   7.0
# 2  7501   0.0
# 3  3648   NaN
# 4  9751   2.0

# %%
# Adds column names
activity_df = pd.DataFrame(joined_data, index=pd.date_range('20240306', periods=5), columns = ('walking', 'cycling'))
activity_df
# Out:
#             walking  cycling
# 2024-03-06     3620     10.0
# 2024-03-07     9466      7.0
# 2024-03-08     7501      0.0
# 2024-03-09     3648      NaN
# 2024-03-10     9751      2.0

# %% [markdown]
# Indexing with Dataframes
#
# Can be indexed using:
# * loc - > named index value
# * iloc - > integer index

# %%
activity_df.loc['2024-03-06']
# Out:
# walking    3620.0
# cycling      10.0
# Name: 2024-03-06 00:00:00, dtype: float64

# %%
activity_df.iloc[0]
# Out:
# walking    3620.0
# cycling      10.0
# Name: 2024-03-06 00:00:00, dtype: float64

# %%
activity_df.loc[:'2024-03-09'] # you can use .loc on dataframes for slicing
# Out:
#             walking  cycling
# 2024-03-06     3620     10.0
# 2024-03-07     9466      7.0
# 2024-03-08     7501      0.0
# 2024-03-09     3648      NaN

# %%
activity_df.iloc[:2] # you can use .iloc on dataframes for slicing
# Out:
#             walking  cycling
# 2024-03-06     3620     10.0
# 2024-03-07     9466      7.0

# %%
activity_df.iloc[:, :] # row, column
# Out:
#             walking  cycling
# 2024-03-06     3620     10.0
# 2024-03-07     9466      7.0
# 2024-03-08     7501      0.0
# 2024-03-09     3648      NaN
# 2024-03-10     9751      2.0

# %%
filepath
df = pd.read_csv(filepath, index_col = 'Id') # uses index_col to set index column from file
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head(5) # views the first n data
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail() # views last data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica

# %%
df['SepalArea'] = df.SepalLengthCm * df.SepalWidthCm
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species  \
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
#      SepalArea
# Id
# ...

# %%
# Add new column for the petal area
df['PetalArea'] = df.PetalLengthCm * df.PetalWidthCm
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species  \
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
#      SepalArea  PetalArea
# ...

# %%
df['abbrev'] = (df.Species.apply)(lambda x:x.replace('Iris-', ''))
# cleans data by removing the Iris- in Species column
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species  \
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# ...

# %%
df.drop(['Species'], axis = 1, inplace = True) # removes the Species column
# axis specifies whether row or column
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  SepalArea  \
# Id
# 1              5.1           3.5            1.4           0.2      17.85
# 2              4.9           3.0            1.4           0.2      14.70
# 3              4.7           3.2            1.3           0.2      15.04
# 4              4.6           3.1            1.5           0.2      14.26
# 5              5.0           3.6            1.4           0.2      18.00
# ..             ...           ...            ...           ...        ...
# 146            6.7           3.0            5.2           2.3      20.10
# 147            6.3           2.5            5.0           1.9      15.75
# 148            6.5           3.0            5.2           2.0      19.50
# 149            6.2           3.4            5.4           2.3      21.08
# 150            5.9           3.0            5.1           1.8      17.70
#
#      PetalArea     abbrev
# Id
# 1         0.28     setosa
# 2         0.28     setosa
# ...

# %%
small_data = pd.concat([df.iloc[:2], df.iloc[-2:]]) # gets the first and last 2 data and joins
small_data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  SepalArea  \
# Id
# 1              5.1           3.5            1.4           0.2      17.85
# 2              4.9           3.0            1.4           0.2      14.70
# 149            6.2           3.4            5.4           2.3      21.08
# 150            5.9           3.0            5.1           1.8      17.70
#
#      PetalArea     abbrev
# Id
# 1         0.28     setosa
# 2         0.28     setosa
# 149      12.42  virginica
# 150       9.18  virginica

# %%
group_size = df.groupby('abbrev').size()
group_size
# Out:
# abbrev
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
df.mean()
# Out:
# <ipython-input-52-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# SepalLengthCm     5.843333
# SepalWidthCm      3.054000
# PetalLengthCm     3.758667
# PetalWidthCm      1.198667
# SepalArea        17.806533
# PetalArea         5.793133
# dtype: float64

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm   SepalArea  \
# count     150.000000    150.000000     150.000000    150.000000  150.000000
# mean        5.843333      3.054000       3.758667      1.198667   17.806533
# std         0.828066      0.433594       1.764420      0.763161    3.368693
# min         4.300000      2.000000       1.000000      0.100000   10.000000
# 25%         5.100000      2.800000       1.600000      0.300000   15.645000
# 50%         5.800000      3.000000       4.350000      1.300000   17.660000
# 75%         6.400000      3.300000       5.100000      1.800000   20.325000
# max         7.900000      4.400000       6.900000      2.500000   30.020000
#
#         PetalArea
# count  150.000000
# mean     5.793133
# std      4.713499
# min      0.110000
# 25%      0.420000
# 50%      5.615000
# 75%      9.690000
# max     15.870000
